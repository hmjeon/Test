# %% [markdown]
# # **OID-Toolkit**

# %% [markdown]
# ## [Step 01] OID-Toolkit 설치

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 20.85 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# %cd /content/OIDv4_ToolKit
# Out:
# /content/OIDv4_ToolKit

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 42.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
# ...

# %% [markdown]
# ## [Step 02] OID-Toolkit 테스트

# %%
# !python main.py -h
# Out:
# usage: main.py
#        [-h]
#        [--Dataset /path/to/OID/csv/]
#        [-y]
#        [--classes list of classes [list of classes ...]]
#        [--type_csv 'train' or 'validation' or 'test' or 'all']
#        [--sub Subset of human verified images or machine generated h or m)]
#        [--image_IsOccluded 1 or 0]
#        [--image_IsTruncated 1 or 0]
#        [--image_IsGroupOf 1 or 0]
#        [--image_IsDepiction 1 or 0]
#        [--image_IsInside 1 or 0]
#        [--multiclasses 0 (default or 1]
#        [--n_threads [default 20]]
#        [--noLabels]
#        [--limit integer number]
#        <command>
#        'downloader',
#        'visualizer'
#        or
#        'ill_downloader'.
#
# Open Image
# Dataset
# Downloader
#
# positional arguments:
#   <command> 'downloader', 'visualizer' or 'ill_downloader'.
#     'downloader
#     ', 'visuali
#     zer' or 'il
#     l_downloade
#     r'.
#
# optional arguments:
#   -h, --help
#     show this
#     help
#     message and
# ...

# %% [markdown]
# ## [Step 03] 다운로드 데이터세트

# %%
# !python main.py downloader --classes Coin Dice Tennis_ball --type_csv train --multiclasses 1 --limit 9
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Coin', 'Dice', 'Tennis ball'] together.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...145%, 0 MB, 29317 KB/s, 0 seconds passed
# ...

# %% [markdown]
# ## [Step 04] Download Dataset to PC

# %%
# !zip -r /content/Dataset.zip /content/OIDv4_ToolKit/OID/Dataset/train/Coin_Dice_Tennisball
# Out:
#   adding: content/OIDv4_ToolKit/OID/Dataset/train/Coin_Dice_Tennisball/ (stored 0%)
#   adding: content/OIDv4_ToolKit/OID/Dataset/train/Coin_Dice_Tennisball/Label/ (stored 0%)
